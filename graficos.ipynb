# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
c_orig = pd.read_csv('./C/dados.csv')
c_trocado = pd.read_csv('./C/dados_iter_trocada.csv')
fortran_orig = pd.read_csv('./Fortran/dados_f_orig.csv')
fortran_trocado = pd.read_csv('./Fortran/dados_f.csv')

# %%
c_orig
# Out:
#       Iteracao      Tempo
# 0            1   0.000004
# 1           20   0.000008
# 2           40   0.000019
# 3           60   0.000042
# 4           80   0.000064
# ...        ...        ...
# 1060     45000  30.143174
# 1061     45250  30.277300
# 1062     45500  29.601225
# 1063     45750  30.029824
# 1064     46000  32.621591
#
# [1065 rows x 2 columns]

# %%
fortran_orig
# Out:
#      Iteracao       Tempo
# 0           1    0.000007
# 1          20    0.000012
# 2          40    0.000018
# 3          60    0.000034
# 4          80    0.000071
# ..        ...         ...
# 896     44000  242.495800
# 897     44500  290.833800
# 898     45000  283.829000
# 899     45500  307.726600
# 900     46000  319.378200
#
# [901 rows x 2 columns]

# %%
plt.plot(c_orig['Iteracao'], c_orig[' Tempo'])
plt.xlabel("Tamanho N")
plt.ylabel("Tempo (s)")
plt.xticks([0, 10000, 20000, 30000, 40000, 46000])
plt.yticks([0, 5, 10, 15, 20, 25, 30, 33])
plt.title("Produto Matriz Vetor na Linguagem C")
plt.savefig("./")
plt.show();

# %%
plt.plot(c_trocado['Iteracao'], c_trocado['Tempo'])
plt.xlabel("Tamanho N")
plt.ylabel("Tempo (s)")
plt.xticks([0, 10000, 20000, 30000, 40000, 46000])
plt.title("Produto Matriz Vetor na Linguagem C (ordem do loop trocada)")
plt.show();

# %%
plt.plot(fortran_orig['Iteracao'], fortran_orig['Tempo'])
plt.xlabel("Tamanho N")
plt.ylabel("Tempo (s)")
plt.xticks([0, 10000, 20000, 30000, 40000, 46000])
plt.title("Produto Matriz Vetor na Linguagem Fortran")
plt.show();

# %%
plt.plot(fortran_trocado['Iteracao'], fortran_trocado['Tempo'])
plt.xlabel("Tamanho N")
plt.ylabel("Tempo (s)")
plt.xticks([0, 10000, 20000, 30000, 40000, 46000])
plt.title("Produto Matriz Vetor na Linguagem Fortran (ordem do loop trocada)")
plt.show();
